# %%
# !pip install matplotlib seaborn pandas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
jdf=pd.read_csv("/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.info
#check how many people leave
print("churn count:")
print(df['Churn'].value_counts())
#for how many months they stay
print('\nAverage customer Tenure:')
print(df["tenure"].mean())
#checking based on gender
pd.crosstab(df['gender'],df['Churn'])
# table of contract vs churn
print(pd.crosstab(df["Contract"],df['Churn']))
#graph
plt.figure(figsize=(15,5)) #graph size
plt.subplot(1,3,1) #churn count
sns.countplot(x='Churn',data=df,palette='Set2')
plt.title('overall churn count')
 #contract based churn
plt.subplot(1,3,2)
sns.countplot(x='Churn', hue='Churn', data=df)
plt.title('Churn by Contract type')
plt.xticks(rotation=45)
#tenure
plt.subplot(1,3,3)
sns.histplot(df['tenure'], bins=30, kde=True, color='purple')
plt.title('Customer Tenure Distribution')

plt.tight_layout()
plt.show()
# Out:
# ...
# churn count:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
#
# Average customer Tenure:
# 32.37114865824223
# Churn             No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48
# /tmp/ipykernel_4391/1832639087.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Churn',data=df,palette='Set2')
